# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from models import LSTMModel, attentional_LSTM
import random
import optuna
from torch.utils.data import DataLoader, TensorDataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
random.seed(42)

# %%
df = yf.download('NVDA', start='2015-01-01', end='2025-01-01')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            NVDA        NVDA        NVDA        NVDA       NVDA
# Date
# 2015-01-02    0.483144    0.486744    0.475463    0.483144  113680000
# 2015-01-05    0.474983    0.484584    0.472823    0.483144  197952000
# 2015-01-06    0.460582    0.476183    0.460102    0.475703  197764000
# 2015-01-07    0.459382    0.468023    0.457942    0.463943  321808000
# 2015-01-08    0.476663    0.479543    0.464423    0.464663  283780000
# ...                ...         ...         ...         ...        ...
# 2024-12-24  140.220001  141.899994  138.649994  140.000000  105157000
# 2024-12-26  139.929993  140.850006  137.729996  139.699997  116205600
# 2024-12-27  137.009995  139.020004  134.710007  138.550003  170582600
# 2024-12-30  137.490005  140.270004  134.020004  134.830002  167734700
# 2024-12-31  134.289993  138.070007  133.830002  138.029999  155659200
#
# [2516 rows x 5 columns]

# %%
data = df[['Close']].values
min(data),  max(data)
# Out:
# (array([0.4593823]), array([148.86975098]))

# %%
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data)

def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length]) #overlapping seqs
        y.append(data[i+seq_length]) #next day close as target 

    X ,y = np.array(X), np.array(y)
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

seq_length = 60  
X, y = create_sequences(data_scaled, seq_length)

train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train.view(-1, seq_length, 1)
X_test = X_test.view(-1, seq_length, 1)

# %%
len(X), y
# Out:
# (2456,
#  tensor([[3.0252e-04],
#          [3.1550e-04],
#          [3.2362e-04],
#          ...,
#          [9.2009e-01],
#          [9.2332e-01],
#          [9.0176e-01]]))

# %%
def train(model, criterion, X, y, epochs=50, device='cpu'):

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    
    model.to(device)
    X, y= X.to(device), y.to(device)
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        
        outputs = model(X_train)
        loss = criterion(outputs, y_train.view(-1, 1))

        loss.backward()
        optimizer.step()

        if (epoch + 1) % 10 == 0:
            print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.6f}")

    return model


def eval(model,X_test, y_test, device=device ):
    model.to(device)
    X_test, y_test = X_test.to(device), y_test.to(device)

    model.eval()
    with torch.no_grad():
        predictions = model(X_test).cpu().numpy()
        actual = y_test.cpu().numpy()

    return predictions, actual

# %%
criterion = nn.MSELoss()

# %%
model = LSTMModel().to(device)


trained_LSTM= train(model, criterion,
                            X_train, y_train, epochs=250, device=device)
LSTM_predictions, actual = eval(trained_LSTM,X_test, y_test)
# Out:
# Epoch [10/250], Loss: 0.004983
# Epoch [20/250], Loss: 0.002819
# Epoch [30/250], Loss: 0.002360
# Epoch [40/250], Loss: 0.002303
# Epoch [50/250], Loss: 0.002134
# Epoch [60/250], Loss: 0.001804
# Epoch [70/250], Loss: 0.000817
# Epoch [80/250], Loss: 0.000144
# Epoch [90/250], Loss: 0.000077
# Epoch [100/250], Loss: 0.000054
# Epoch [110/250], Loss: 0.000047
# Epoch [120/250], Loss: 0.000042
# Epoch [130/250], Loss: 0.000040
# Epoch [140/250], Loss: 0.000038
# Epoch [150/250], Loss: 0.000036
# Epoch [160/250], Loss: 0.000036
# Epoch [170/250], Loss: 0.000035
# Epoch [180/250], Loss: 0.000034
# Epoch [190/250], Loss: 0.000034
# Epoch [200/250], Loss: 0.000033
# Epoch [210/250], Loss: 0.000033
# Epoch [220/250], Loss: 0.000033
# Epoch [230/250], Loss: 0.000033
# Epoch [240/250], Loss: 0.000032
# Epoch [250/250], Loss: 0.000032

# %% [markdown]
# * Bidirectional LSTM (Bi-LSTM) → Captures both past and future context.
# * Attention Mechanism
# * Hybrid Models (LSTM + ARIMA)
# * feats : Volume, Moving Averages (SMA, EMA), RSI, MACD (Technical Indicators), "News Sentiment Data"

# %%
print(LSTMModel.__init__.__code__.co_varnames)
# Out:
# ('self', 'input_size', 'hidden_size', 'num_layers', 'output_size', 'bidirectional', 'fc_input_size')

# %%
Bi_LSTM = LSTMModel(input_size=1, hidden_size=64, num_layers=2, output_size=1,bidirectional=True)

trained_Bi_LSTM= train(Bi_LSTM, criterion, 
                            X_train, y_train, epochs=250, device=device)
# Out:
# Epoch [10/250], Loss: 0.002578
# Epoch [20/250], Loss: 0.002494
# Epoch [30/250], Loss: 0.002292
# Epoch [40/250], Loss: 0.001957
# Epoch [50/250], Loss: 0.001156
# Epoch [60/250], Loss: 0.000488
# Epoch [70/250], Loss: 0.000193
# Epoch [80/250], Loss: 0.000046
# Epoch [90/250], Loss: 0.000034
# Epoch [100/250], Loss: 0.000034
# Epoch [110/250], Loss: 0.000030
# Epoch [120/250], Loss: 0.000026
# Epoch [130/250], Loss: 0.000025
# Epoch [140/250], Loss: 0.000025
# Epoch [150/250], Loss: 0.000024
# Epoch [160/250], Loss: 0.000024
# Epoch [170/250], Loss: 0.000023
# Epoch [180/250], Loss: 0.000023
# Epoch [190/250], Loss: 0.000023
# Epoch [200/250], Loss: 0.000022
# Epoch [210/250], Loss: 0.000022
# Epoch [220/250], Loss: 0.000022
# Epoch [230/250], Loss: 0.000021
# Epoch [240/250], Loss: 0.000021
# Epoch [250/250], Loss: 0.000021

# %%
Bi_LSTM_predictions, actual = eval(trained_Bi_LSTM,X_test, y_test)

# %%
#back to og scale
LSTM_predictions = scaler.inverse_transform(LSTM_predictions)
Bi_LSTM_predictions= scaler.inverse_transform(Bi_LSTM_predictions)
actual = scaler.inverse_transform(actual.reshape(-1, 1))

plt.figure(figsize=(12,6))
plt.plot(actual, label="Actual Prices", color='blue')
plt.plot(LSTM_predictions, label="Predicted Prices LSTM", color='red')
plt.plot(Bi_LSTM_predictions, label="Predicted Prices Bidirectionnal LSTM", color='green')


plt.plot()
plt.legend()
plt.show()

# %% [markdown]
# ### attention mechanisms(time-wise) on LSTM :
# * Instead of just using the last hidden state, Attention learns to assign weights to different time steps based on their relevance and then compute weighted sum of all hidden states

# %%
model = attentional_LSTM(input_size=1, hidden_size=128, num_layers=3, output_size=1,attention_size= 64, bidirectional=True).to(device)


trained_model = train(model, criterion, 
                            X_train, y_train, 
                            epochs=250, device=device)
# Out:
# Epoch [10/250], Loss: 0.002499
# Epoch [20/250], Loss: 0.002549
# Epoch [30/250], Loss: 0.002182
# Epoch [40/250], Loss: 0.000494
# Epoch [50/250], Loss: 0.000328
# Epoch [60/250], Loss: 0.000140
# Epoch [70/250], Loss: 0.000128
# Epoch [80/250], Loss: 0.000128
# Epoch [90/250], Loss: 0.000122
# Epoch [100/250], Loss: 0.000117
# Epoch [110/250], Loss: 0.000112
# Epoch [120/250], Loss: 0.000104
# Epoch [130/250], Loss: 0.000089
# Epoch [140/250], Loss: 0.000075
# Epoch [150/250], Loss: 0.000064
# Epoch [160/250], Loss: 0.000058
# Epoch [170/250], Loss: 0.000056
# Epoch [180/250], Loss: 0.000054
# Epoch [190/250], Loss: 0.000051
# Epoch [200/250], Loss: 0.000056
# Epoch [210/250], Loss: 0.000051
# Epoch [220/250], Loss: 0.000050
# Epoch [230/250], Loss: 0.000046
# Epoch [240/250], Loss: 0.000036
# Epoch [250/250], Loss: 0.000031

# %%
attentional_LSTM_predictions, actual= eval(trained_model ,X_test, y_test)

# %%
attentional_LSTM_predictions= scaler.inverse_transform(attentional_LSTM_predictions)
actual = scaler.inverse_transform(actual.reshape(-1, 1))

plt.figure(figsize=(12,6))
plt.plot(actual, label="Actual Prices", color='blue')
plt.plot(attentional_LSTM_predictions, label="Predicted Prices attentional LSTM", color='red')

plt.plot()
plt.legend()
plt.show()

# %%
i=0
model_save_path = f"attentional_LSTM_model_{i}.pth"
i=+1
torch.save({
    'model_state_dict': model.state_dict(),
    'hyperparameters': {
        'input_size': 1,
        'hidden_size': 128,
        'num_layers': 3,
        'output_size': 1,
        'bidirectional': True,
        'attention_size': 64,
        'optimizer': 'Adam',
        'learning_rate': 0.001,
        'epochs': 2500
    }
}, model_save_path)

# %%
def objective(trial):
    hidden_size = trial.suggest_categorical("hidden_size", [32, 64, 128, 256])
    num_layers = trial.suggest_int("num_layers", 1, 4)
    attention_size = trial.suggest_categorical("attention_size", [8, 16, 32, 64])
    bidirectional = trial.suggest_categorical("bidirectional", [True, False])
    # learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-2)
    learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
    epochs = trial.suggest_categorical("epochs", [50, 100, 200])

    # DataLoader for batching
    train_dataset = TensorDataset(X_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    model = attentional_LSTM(input_size=1, hidden_size=hidden_size, num_layers=num_layers, 
                             output_size=1, attention_size=attention_size, bidirectional=bidirectional)
    model.to(device)

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            optimizer.zero_grad()

            outputs = model(batch_X)
            loss = criterion(outputs, batch_y.view(-1, 1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss / len(train_loader):.6f}")

    # Evaluation
    predictions, actual = eval(model, X_test, y_test, device)
    mse = nn.MSELoss()(torch.tensor(predictions), torch.tensor(actual))

    return mse.item()

# %%
study = optuna.create_study(direction="minimize")  # We want to minimize MSE
study.optimize(objective, n_trials=30) 

print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-02-15 18:46:30,770] A new study created in memory with name: no-name-3799e34c-18a1-45e1-8c45-90587bdf2ad8
# Epoch 10/50, Loss: 0.000020
# [W 2025-02-15 18:49:48,896] Trial 0 failed with parameters: {'hidden_size': 256, 'num_layers': 3, 'attention_size': 32, 'bidirectional': True, 'learning_rate': 0.0010494713479549916, 'batch_size': 16, 'epochs': 50} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/cw/0t2jzw0d1dg1rj3qj57z9_qh0000gn/T/ipykernel_39585/2683035344.py", line 31, in objective
#     loss.backward()
#   File "/Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages/torch/_tensor.py", line 492, in backward
#     torch.autograd.backward(
#   File "/Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages/torch/autograd/__init__.py", line 251, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
# [W 2025-02-15 18:49:48,898] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 study = optuna.create_study(direction="minimize")  # We want to minimize MSE
# ----> 2 study.optimize(objective, n_trials=30)
#       4 print("Best hyperparameters:", study.best_params)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[19], line 31, in objective(trial)
#      29 outputs = model(batch_X)
#      30 loss = criterion(outputs, batch_y.view(-1, 1))
# ---> 31 loss.backward()
#      32 optimizer.step()
#      33 total_loss += loss.item()
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %% [markdown]
# #### Transformer Models for Time Series:
#
# &rarr; Temporal Fusion Transformer (TFT)
#
# &rarr; Informer: Sparse Attention Transformer
#
# &rarr; DeepAR + Transformers

# %%
# !pip install pytorch-forecasting
# Out:
# Collecting pytorch-forecasting
#   Downloading pytorch_forecasting-1.3.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<=3.0.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pytorch-forecasting) (1.23.5)
# Requirement already satisfied: torch!=2.0.1,<3.0.0,>=2.0.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pytorch-forecasting) (2.1.1)
# Collecting lightning<3.0.0,>=2.0.0 (from pytorch-forecasting)
#   Downloading lightning-2.5.0.post0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: scipy<2.0,>=1.8 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pytorch-forecasting) (1.11.4)
# Requirement already satisfied: pandas<3.0.0,>=1.3.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pytorch-forecasting) (1.5.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.2 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pytorch-forecasting) (1.3.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (6.0)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2023.10.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading lightning_utilities-0.12.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (23.0)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (4.66.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from lightning<3.0.0,>=2.0.0->pytorch-forecasting) (4.12.2)
# Collecting pytorch-lightning (from lightning<3.0.0,>=2.0.0->pytorch-forecasting)
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pandas<3.0.0,>=1.3.0->pytorch-forecasting) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from pandas<3.0.0,>=1.3.0->pytorch-forecasting) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from scikit-learn<2.0,>=1.2->pytorch-forecasting) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from scikit-learn<2.0,>=1.2->pytorch-forecasting) (2.2.0)
# Requirement already satisfied: filelock in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.12.0)
# Requirement already satisfied: sympy in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (1.11.1)
# Requirement already satisfied: networkx in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (3.1.2)
# Requirement already satisfied: requests in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (3.8.3)
# Requirement already satisfied: setuptools in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (66.0.0)
# Requirement already satisfied: six>=1.5 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<3.0.0,>=1.3.0->pytorch-forecasting) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from jinja2->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from sympy->torch!=2.0.1,<3.0.0,>=2.0.0->pytorch-forecasting) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/grace/miniconda3/envs/tf/lib/python3.10/site-packages (from requests->fsspec[http]<2026.0,>=2022.5.0->lightning<3.0.0,>=2.0.0->pytorch-forecasting) (2023.11.17)
# Downloading pytorch_forecasting-1.3.0-py3-none-any.whl (197 kB)
# Downloading lightning-2.5.0.post0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 13.4 MB/s eta 0:00:00
# Downloading lightning_utilities-0.12.0-py3-none-any.whl (28 kB)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 32.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 27.5 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning, lightning, pytorch-forecasting
# Successfully installed lightning-2.5.0.post0 lightning-utilities-0.12.0 pytorch-forecasting-1.3.0 pytorch-lightning-2.5.0.post0 torchmetrics-1.6.1
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
